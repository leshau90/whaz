# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.randint(0,high=10,size=(3,3))
x
# Out:
# array([[9, 1, 8],
#        [5, 2, 7],
#        [7, 5, 6]])

# %%
plt.plot(x)

# %%
x.reshape([9,1])
# Out:
# array([[9],
#        [1],
#        [8],
#        [5],
#        [2],
#        [7],
#        [7],
#        [5],
#        [6]])
